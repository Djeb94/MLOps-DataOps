# %% [markdown]
# ## Modèle en production
#
# Laurent Cetinsoy - Datadidacte
#
# Une des supposition centrale pour qu'un modèle de machine learning marche est que la distribution des données ne diffère pas de celle des données d'entrainement.
#
# On ne peut garantir la généralisation d'un modèle que si la distribution des données est similaire à celle de la distribution $ X_{prod} \tilde{} \,  P_{train}$
#
# Ainsi, si les données que le modèle voient en production n'ont pas la même distribution (ne ressemblent pas) aux données de train, alors le modèle aura peu de chance de faire de bonne prédictions.
#
# Il est donc important de surveille les données vues par le modèle en production.
#
# Pour cela on va mesurer ce qu'on appelle le Data drift : on va mesurer à quel point les données s'écartent des données de train.
#
# Et on pourra ainsi lever une alerte si c'est le cas.

# %% [markdown]
# ## Utilisation Eurybia

# %% [markdown]
# En consultant la documentation de Eurybia (https://eurybia.readthedocs.io/en/latest/overview.html), expliquer le principe de fonctionnement de Euribya :
#
# - A quoi sert le modèle de classification ?
# - A-t-on besoin d’avoir les labels issus de la production pour pouvoir utiliser cette approche ?
# - Quel est le critère pour déterminer qu’il y a un data-drift ?

# %% [markdown]
# Eurybia crée un modèle de classification binaire qui cherche à déterminer si une donnée vient du dataset d'entraînement (baseline) ou du dataset de production (current). Si le modèle arrive facilement à différencier les deux datasets, cela signifie que leurs distributions sont différentes et qu'il y a donc du data drift.
#
# Non. Pour détecter le data drift, Eurybia compare les variables d'entrée des données d'entraînement et de production. Les labels de production ne sont donc pas nécessaires. Ils seraient nécessaires pour mesurer directement les performances du modèle en production.
#
# Eurybia utilise l'AUC du modèle de classification du drift. Une AUC proche de 0,5 signifie que les deux distributions sont similaires, donc pas de drift. Plus l'AUC se rapproche de 1, plus le modèle arrive à distinguer les deux datasets et plus le drift est important.

# %% [markdown]
# Installer eurybia

# %%
# !pip install eurybia
# Out:
# Requirement already satisfied: eurybia in /usr/local/lib/python3.13/dist-packages (1.4.0)
# Requirement already satisfied: pandas<3,>=2 in /usr/local/lib/python3.13/dist-packages (from eurybia) (2.2.3)
# Requirement already satisfied: catboost>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from eurybia) (1.2.10)
# Requirement already satisfied: panel>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from eurybia) (1.9.4)
# Requirement already satisfied: jinja2>=2.11.0 in /usr/local/lib/python3.13/dist-packages (from eurybia) (3.1.6)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from eurybia) (1.16.3)
# Requirement already satisfied: seaborn>=0.10.1 in /usr/local/lib/python3.13/dist-packages (from eurybia) (0.13.2)
# Requirement already satisfied: shapash>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from eurybia) (2.9.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.13/dist-packages (from eurybia) (5.24.1)
# Requirement already satisfied: kaleido<1.0.0,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from eurybia) (0.2.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.13/dist-packages (from catboost>=1.0.1->eurybia) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from catboost>=1.0.1->eurybia) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.13/dist-packages (from catboost>=1.0.1->eurybia) (2.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from catboost>=1.0.1->eurybia) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=2.11.0->eurybia) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2->eurybia) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2->eurybia) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2->eurybia) (2026.3)
# Requirement already satisfied: bokeh<3.10.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (3.8.2)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (2.2.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (3.10.3)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (0.6.1)
# Requirement already satisfied: narwhals>=2 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (2.25.0)
# Requirement already satisfied: nh3 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (0.3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (26.3)
# Requirement already satisfied: panel-material-ui>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (0.14.2)
# Requirement already satisfied: param<3.0,>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (2.4.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (3.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from panel>=1.4.1->eurybia) (4.16.0)
# Requirement already satisfied: category_encoders>=2.6.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (2.11.1)
# Requirement already satisfied: dash-bootstrap-components>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (1.7.1)
# Requirement already satisfied: dash-core-components>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (2.0.0)
# Requirement already satisfied: dash-daq>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (0.6.0)
# Requirement already satisfied: dash-html-components>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (2.0.0)
# Requirement already satisfied: dash-renderer==1.8.3 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (1.8.3)
# Requirement already satisfied: dash-table>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (5.0.0)
# Requirement already satisfied: dash<3.0.0,>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (2.18.2)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (3.0.3)
# Requirement already satisfied: nbformat>5.8.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (5.11.1)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (0.61.2)
# Requirement already satisfied: scikit-learn<1.9.0,>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (1.8.0)
# Requirement already satisfied: shap>=0.46.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (0.52.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from shapash>=2.0.0->eurybia) (2.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly->eurybia) (9.1.4)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.13/dist-packages (from bokeh<3.10.0,>=3.7.0->panel>=1.4.1->eurybia) (1.3.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.13/dist-packages (from bokeh<3.10.0,>=3.7.0->panel>=1.4.1->eurybia) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.13/dist-packages (from bokeh<3.10.0,>=3.7.0->panel>=1.4.1->eurybia) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.13/dist-packages (from bokeh<3.10.0,>=3.7.0->panel>=1.4.1->eurybia) (6.5.7)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.13/dist-packages (from bokeh<3.10.0,>=3.7.0->panel>=1.4.1->eurybia) (2026.3.0)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.13/dist-packages (from dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (3.0.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.13/dist-packages (from dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (9.0.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.13/dist-packages (from dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (80.10.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.13/dist-packages (from Flask>=1.0.4->shapash>=2.0.0->eurybia) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.13/dist-packages (from Flask>=1.0.4->shapash>=2.0.0->eurybia) (8.5.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.13/dist-packages (from Flask>=1.0.4->shapash>=2.0.0->eurybia) (1.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost>=1.0.1->eurybia) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost>=1.0.1->eurybia) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost>=1.0.1->eurybia) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost>=1.0.1->eurybia) (3.3.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat>5.8.0->shapash>=2.0.0->eurybia) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat>5.8.0->shapash>=2.0.0->eurybia) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.13/dist-packages (from nbformat>5.8.0->shapash>=2.0.0->eurybia) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.13/dist-packages (from nbformat>5.8.0->shapash>=2.0.0->eurybia) (5.7.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.60.0->shapash>=2.0.0->eurybia) (0.44.0)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.9.0,>=1.8.0->shapash>=2.0.0->eurybia) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.9.0,>=1.8.0->shapash>=2.0.0->eurybia) (3.6.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.13/dist-packages (from shap>=0.46.0->shapash>=2.0.0->eurybia) (0.0.8)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.13/dist-packages (from shap>=0.46.0->shapash>=2.0.0->eurybia) (3.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py->panel>=1.4.1->eurybia) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.1->eurybia) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.1->eurybia) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.1->eurybia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->panel>=1.4.1->eurybia) (2026.7.22)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat>5.8.0->shapash>=2.0.0->eurybia) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat>5.8.0->shapash>=2.0.0->eurybia) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat>5.8.0->shapash>=2.0.0->eurybia) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat>5.8.0->shapash>=2.0.0->eurybia) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>5.8.0->shapash>=2.0.0->eurybia) (4.11.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib-metadata->dash<3.0.0,>=2.3.1->shapash>=2.0.0->eurybia) (4.1.0)

# %%
# !pip install jupyter_bokeh
# Out:
# Requirement already satisfied: jupyter_bokeh in /usr/local/lib/python3.13/dist-packages (4.1.0)
# Requirement already satisfied: bokeh==3.* in /usr/local/lib/python3.13/dist-packages (from jupyter_bokeh) (3.8.2)
# Requirement already satisfied: ipywidgets==8.* in /usr/local/lib/python3.13/dist-packages (from jupyter_bokeh) (8.1.9)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (2.25.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (2.1.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (26.3)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (6.5.7)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.13/dist-packages (from bokeh==3.*->jupyter_bokeh) (2026.3.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.13/dist-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets==8.*->jupyter_bokeh) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets==8.*->jupyter_bokeh) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in /usr/local/lib/python3.13/dist-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in /usr/local/lib/python3.13/dist-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (80.10.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2026.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.17.0)

# %%
import pandas as pd

df = pd.read_csv("/content/houses_2024.csv")

df.head()
# Out:
#          size  nb_rooms  garden orientation          price
# 0  215.775096         1       0       Ouest  243048.717637
# 1  247.064976         2       0        Nord  248116.081979
# 2  134.107329         2       1       Ouest  291773.127311
# 3  196.242198         3       1       Ouest  328799.458161
# 4  154.396906         1       1         Est  274069.213761

# %% [markdown]
# Utiliser eurybia pour monitorer la distribution des données. Dans un premier temps faire en sorte que les données de prod (df_current) soient de la même distribution que vos données d’entraînement. Pour cela vous pouvez split le dataset en deux et décider que l'un est X_train et l'autre est X_prod. Vérifier que Eurybia pense que le modèle ne drift pas. Attention à ne pas inclure le label (qui serait ici price)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=["price"])

X_train, X_prod = train_test_split(
    X,
    test_size=0.5,
    random_state=42
)

print("X_train :", X_train.shape)
print("X_prod  :", X_prod.shape)
# Out:
# X_train : (400, 4)
# X_prod  : (400, 4)

# %% [markdown]
# Faire en sorte d'introduire un drift dans vos données. Par exemple (méthode assez bourine) ajouter +3 ou +4 à la colonne nb_rooms. Relancer eurybia et vérifier que la performance du modèle est bonne et qu'il y a donc un datadrift

# %%
from eurybia import SmartDrift

sd = SmartDrift(
    df_current=X_prod,
    df_baseline=X_train
)

sd.compile()

print("AUC :", sd.auc)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c01c58ba-1c1a-4ceb-9e41-31802293f955'>
#   <div id="c1bb3e96-d33a-4ada-a098-b1051dc22ae7" data-root-id="c01c58ba-1c1a-4ceb-9e41-31802293f955" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"da837958-fd38-4920-8542-c6426aa59fb1":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"ef3fe18e-6f83-4009-9ebb-1c025e56aa35","attributes":{"notifications":{"type":"object","name":"Notifications","id":"f4ef0f9b-20ed-4919-8d0e-6e37a7b659ff"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c01c58ba-1c1a-4ceb-9e41-31802293f955"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"20608bc7-2575-46b3-9450-f5b7ad184977","attributes":{"plot_id":"c01c58ba-1c1a-4ceb-9e41-31802293f955","comm_id":"c2251f3864c04b5fb3de7f9684786c7b","client_comm_id":"09d44bc61a48498a81e363dffec85355"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"da837958-fd38-4920-8542-c6426aa59fb1","roots":{"c01c58ba-1c1a-4ceb-9e41-31802293f955":"c1bb3e96-d33a-4ada-a098-b1051dc22ae7"},"root_ids":["c01c58ba-1c1a-4ceb-9e41-31802293f955"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# INFO: Shap explainer type - <shap.explainers._tree.TreeExplainer object at 0x7f5981d3bb60>
# AUC : 0.5688

# %%
X_prod_drift = X_prod.copy()

X_prod_drift["nb_rooms"] = X_prod_drift["nb_rooms"] + 4

sd_drift = SmartDrift(
    df_current=X_prod_drift,
    df_baseline=X_train
)

sd_drift.compile()

print("AUC avec drift :", sd_drift.auc)
# Out:
# INFO: Shap explainer type - <shap.explainers._tree.TreeExplainer object at 0x7f5981c29d10>
# AUC avec drift : 1.0

# %% [markdown]
# Faire en sorte de faire un drift plus subtile mais remarquable. Est-il détectable avec Eurybia ?

# %%
X_prod_subtle = X_prod.copy()

X_prod_subtle["nb_rooms"] = X_prod_subtle["nb_rooms"] + 1

sd_subtle = SmartDrift(
    df_current=X_prod_subtle,
    df_baseline=X_train
)

sd_subtle.compile()

print("AUC avec drift subtil :", sd_subtle.auc)
# Out:
# INFO: Shap explainer type - <shap.explainers._tree.TreeExplainer object at 0x7f5981d2f360>
# AUC avec drift subtil : 0.7435499999999999

# %% [markdown]
# Oui, Eurybia permet de détecter un drift plus subtil. Dans notre test, nous avons ajouté seulement +1 à la variable `nb_rooms`. L'AUC obtenue est de 0.74355, ce qui est nettement supérieur à 0.5. Eurybia détecte donc une différence entre les données d'entraînement et les données de production.

# %% [markdown]
# ## Alibaba detect
#
# Dans cette partie on va utiliser la librairie https://github.com/SeldonIO/alibi-detect pour faire la détection de problèmes
# Installer la librairie avec pip

# %% [markdown]
# Charger le jeu de donnée cifar10 avec keras et récupérer le train et le test puis,
#
# Normaliser les données de train en faisant un MinMaxScaling (diviser par 255)

# %% [markdown]
# Dans le sous package alibbi_detect.datasets importer les  fonction fetch_cifar10c et corruption_types_cifar10c

# %% [markdown]
# Afficher les types de corruption de données disponible avec la fonction corruption_types_cifar10c

# %% [markdown]
# Avec la fonction fetch_cifar10c récupérer des exemples corrompus de donnée ressemblant à cifar 10 et les stocker dans des variable X_corrupted et y_corrupted.
#
# Vous choisirez 1 ou 2 corruptions parmis les suivantes : ['gaussian_noise', 'motion_blur', 'brightness', 'pixelate']
#
# Vous spécifirez les argument severity=5 et return_X_y=True
# attention le dataset peut être lourd si vous utilisez bcp de corruptions

# %% [markdown]
# Normaliser les images corrompues

# %% [markdown]
# Afficher plusieurs des images corrompues.

# %% [markdown]
# On va maintenant prendre un modèle entraîné sur cifar10 pour voir l'impact des performances sur le modèle.
#
# Avec la fonction  fetch_tf_model du module alibi_detect.utils.fetching, charger le modèle préentraîné resnet32 sur cifar10

# %%
from alibi_detect.utils.fetching import fetch_tf_model, fetch_detector
dataset = 'cifar10'
model_name = 'resnet32'
model = fetch_tf_model(dataset, model_name)

# %% [markdown]
# Calculer la performance du model sur le jeu de train et de test

# %% [markdown]
# Calculer la performance du modèle sur le jeu de donnée corrompu. Vous devriez observer qu'il chute significativement

# %% [markdown]
# On va maintenant voir comment détecter les changement de distributions de données.
#
# Pour les données non tabulaire ou à haute dimension on procéde généralement en deux étapes :
#
# 1. Faire une réduction de dimension
# 2. Faire un test permettant de voir si les données projetées ont changé de distribution ou pas
#
# Il existe plusieurs manières de faire de la réduction de dimension. La plus classique est la PCA.
#
# Il est possible également d'utiliser des Auto-encoder
#
# Le code suivant permet de créer la première partie (l'encoder) d'un auto-encoder simple qui nous servira à réduire les dimension des données.

# %%
from functools import partial
from tensorflow.keras.layers import Conv2D, Dense, Flatten, InputLayer, Reshape
from alibi_detect.cd.tensorflow import preprocess_drift

tf.random.set_seed(0)

# define encoder
encoding_dim = 32
encoder_net = tf.keras.Sequential(
  [
      InputLayer(input_shape=(32, 32, 3)),
      Conv2D(64, 4, strides=2, padding='same', activation=tf.nn.relu),
      Conv2D(128, 4, strides=2, padding='same', activation=tf.nn.relu),
      Conv2D(512, 4, strides=2, padding='same', activation=tf.nn.relu),
      Flatten(),
      Dense(encoding_dim,)
  ]
)

# %% [markdown]
# Le drift detector a besoin d'une donnée de référence afin d'effectuer la comparaison avec les données à monitorer.
# Créer une variable X_ref avec un échantillon aléatoire des données de test

# %% [markdown]
# A quoi sert le test statistique kolmogorov smirnoff ?

# %% [markdown]
# Instancier la classe KSDrift dans une variable nommée **detector**
#
# Il faut lui passer le dataset de reference, une p value (prendre 0.05) et une fonction permettant de faire le preprocessing. On a créé la fonction pour vous

# %%
from alibi_detect.cd.tensorflow import preprocess_drift
preprocess_function = partial(preprocess_drift, model=encoder_net, batch_size=32)

# %% [markdown]
# A laide du Drift detector et la méthode predict faire des prediction sur les données de test et sur les données corrompue pour voir si il détecte un changement de distribution
